# %% [markdown]
# # Indian Food Detection with Deep Learning
#
# **Mayank Pujara |** mayankpujara25@gmail.com
#
# The project aims to utilize deep learning techniques for computer vision to detect and classify various Indian food items in images. With a dataset of 4000 images spanning 80 different categories, the goal is to create a model that can accurately identify and categorize the diverse range of Indian cuisines based on locally available spices, herbs, vegetables, and fruits.

# %% [markdown]
# ---
# ## Importing necessary Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os
from PIL import Image
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.python.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, CSVLogger
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Loading and Exploring the Dataset

# %%
dataDirectory = "Indian Food Images"

# %%
subdirectories = [subdir for subdir in os.listdir(dataDirectory) if os.path.isdir(os.path.join(dataDirectory, subdir))]

print(f"Number of subdirectories: {len(subdirectories)}")
print(f"Subdirectories: {subdirectories}")
# Out:
# Number of subdirectories: 80
# Subdirectories: ['adhirasam', 'aloo_gobi', 'aloo_matar', 'aloo_methi', 'aloo_shimla_mirch', 'aloo_tikki', 'anarsa', 'ariselu', 'bandar_laddu', 'basundi', 'bhatura', 'bhindi_masala', 'biryani', 'boondi', 'butter_chicken', 'chak_hao_kheer', 'cham_cham', 'chana_masala', 'chapati', 'chhena_kheeri', 'chicken_razala', 'chicken_tikka', 'chicken_tikka_masala', 'chikki', 'daal_baati_churma', 'daal_puri', 'dal_makhani', 'dal_tadka', 'dharwad_pedha', 'doodhpak', 'double_ka_meetha', 'dum_aloo', 'gajar_ka_halwa', 'gavvalu', 'ghevar', 'gulab_jamun', 'imarti', 'jalebi', 'kachori', 'kadai_paneer', 'kadhi_pakoda', 'kajjikaya', 'kakinada_khaja', 'kalakand', 'karela_bharta', 'kofta', 'kuzhi_paniyaram', 'lassi', 'ledikeni', 'litti_chokha', 'lyangcha', 'maach_jhol', 'makki_di_roti_sarson_da_saag', 'malapua', 'misi_roti', 'misti_doi', 'modak', 'mysore_pak', 'naan', 'navrattan_korma', 'palak_paneer', 'paneer_butter_masala', 'phirni', 'pithe', 'poha', 'poornalu', 'pootharekulu', 'qubani_ka_meetha', 'rabri', 'rasgulla', 'ras_malai', 'sandesh', 'shankarpali', 'sheera', 'sheer_korma', 'shrikhand', 'sohan_halwa', 'sohan_papdi', 'sutar_feni', 'unni_appam']

# %% [markdown]
# ## Data Preprocessing for Deep Learning
#
# I performed the following steps:<br><br>
# **1. Resizing**<br>
# **2. Normalizing the Dataset**<br>
# **3. Data Augmentation**

# %%
datagen = ImageDataGenerator(
    rescale=1./255,          # Normalize pixel values to be between 0 and 1
    rotation_range=20,       # Randomly rotate images by up to 20 degrees
    width_shift_range=0.2,   # Randomly shift images horizontally by up to 20% of the width
    height_shift_range=0.2,  # Randomly shift images vertically by up to 20% of the height
    shear_range=0.2,         
    zoom_range=0.2,        
    horizontal_flip=True,    
    vertical_flip=False,     
    fill_mode='nearest'      
)

batchSize = 32
dataGenerator = datagen.flow_from_directory(
    dataDirectory,
    target_size=(200, 200),   # Resize images to 200x200 pixels
    batch_size=batchSize,
    class_mode='categorical'  
)

augmentedImages, _ = next(dataGenerator)
# Out:
# Found 4000 images belonging to 80 classes.

# %%
imageHeight,imageWidth=200,200 
batchSize=32

# %% [markdown]
# ### Splitting the Dataset into Training Dataset and Validation Dataset

# %%
trainDataset = tf.keras.preprocessing.image_dataset_from_directory(
  dataDirectory,
  validation_split=0.2,
  subset="training",
  seed=35,
  image_size=(imageHeight, imageWidth),
  batch_size=batchSize)
# Out:
# Found 4000 files belonging to 80 classes.
# Using 3200 files for training.

# %%
validationDataset = tf.keras.preprocessing.image_dataset_from_directory(
  dataDirectory,
  validation_split=0.2,
  subset="validation",
  seed=35,
  image_size=(imageHeight, imageWidth),
  batch_size=batchSize)
# Out:
# Found 4000 files belonging to 80 classes.
# Using 800 files for validation.

# %% [markdown]
# ### Visualizing the images

# %%
classNames = trainDataset.class_names

plt.figure(figsize=(15, 15))
for images, labels in trainDataset.take(1): 
    for i in range(min(80, batchSize)): 
        ax = plt.subplot(10, 8, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        plt.title(classNames[labels[i]])
        plt.axis("off")
plt.show()

# %% [markdown]
# ---
# ## Implementation of the ResNet Model

# %%
resnetModel = Sequential()

pretrainedModel= tf.keras.applications.ResNet50(include_top=False,
                   input_shape=(200,200,3),
                   pooling='avg',classes=80,
                   weights='imagenet')
for layer in pretrainedModel.layers:
        layer.trainable=False

resnetModel.add(pretrainedModel)
resnetModel.add(Flatten())
resnetModel.add(Dense(1024, activation='relu'))
resnetModel.add(Dense(512, activation='relu'))
resnetModel.add(Dense(80, activation='softmax'))
# Out:
# WARNING:tensorflow:From C:\Python310\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Python310\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
resnetModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 2048)              23587712
#
#  module_wrapper (ModuleWrap  (None, 2048)              0
#  per)
#
#  module_wrapper_1 (ModuleWr  (None, 1024)              2098176
#  apper)
#
#  module_wrapper_2 (ModuleWr  (None, 512)               524800
#  apper)
#
#  module_wrapper_3 (ModuleWr  (None, 80)                41040
#  apper)
#
# =================================================================
# Total params: 26251728 (100.14 MB)
# Trainable params: 2664016 (10.16 MB)
# Non-trainable params: 23587712 (89.98 MB)
# _________________________________________________________________

# %%
resnetModel.compile(optimizer=Adam(learning_rate=0.0001), 
                     loss='sparse_categorical_crossentropy', 
                     metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=4)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2)
csv_logger = CSVLogger('ResNet50_Training_History.csv')
epochs=15
history = resnetModel.fit(
  trainDataset,
  validation_data=validationDataset,
  epochs=epochs,
  callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/15
# WARNING:tensorflow:From C:\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 100/100 [==============================] - 194s 2s/step - loss: 4.1138 - accuracy: 0.0859 - val_loss: 3.6770 - val_accuracy: 0.1612 - lr: 1.0000e-04
# Epoch 2/15
# 100/100 [==============================] - 185s 2s/step - loss: 2.9418 - accuracy: 0.3162 - val_loss: 2.9282 - val_accuracy: 0.2600 - lr: 1.0000e-04
# Epoch 3/15
# 100/100 [==============================] - 184s 2s/step - loss: 2.1128 - accuracy: 0.4925 - val_loss: 2.5612 - val_accuracy: 0.3475 - lr: 1.0000e-04
# Epoch 4/15
# 100/100 [==============================] - 184s 2s/step - loss: 1.5648 - accuracy: 0.6244 - val_loss: 2.3755 - val_accuracy: 0.3812 - lr: 1.0000e-04
# Epoch 5/15
# 100/100 [==============================] - 186s 2s/step - loss: 1.1763 - accuracy: 0.7475 - val_loss: 2.2560 - val_accuracy: 0.4250 - lr: 1.0000e-04
# Epoch 6/15
# 100/100 [==============================] - 184s 2s/step - loss: 0.9017 - accuracy: 0.8269 - val_loss: 2.1324 - val_accuracy: 0.4400 - lr: 1.0000e-04
# Epoch 7/15
# 100/100 [==============================] - 188s 2s/step - loss: 0.6846 - accuracy: 0.8869 - val_loss: 2.1278 - val_accuracy: 0.4525 - lr: 1.0000e-04
# Epoch 8/15
# 100/100 [==============================] - 185s 2s/step - loss: 0.5207 - accuracy: 0.9272 - val_loss: 2.0462 - val_accuracy: 0.4875 - lr: 1.0000e-04
# Epoch 9/15
# 100/100 [==============================] - 186s 2s/step - loss: 0.4019 - accuracy: 0.9547 - val_loss: 2.0192 - val_accuracy: 0.4988 - lr: 1.0000e-04
# Epoch 10/15
# 100/100 [==============================] - 184s 2s/step - loss: 0.3069 - accuracy: 0.9769 - val_loss: 2.0325 - val_accuracy: 0.4850 - lr: 1.0000e-04
# Epoch 11/15
# 100/100 [==============================] - 184s 2s/step - loss: 0.2327 - accuracy: 0.9859 - val_loss: 1.9997 - val_accuracy: 0.4938 - lr: 1.0000e-04
# Epoch 12/15
# 100/100 [==============================] - 185s 2s/step - loss: 0.1815 - accuracy: 0.9897 - val_loss: 1.9756 - val_accuracy: 0.5050 - lr: 1.0000e-04
# Epoch 13/15
# 100/100 [==============================] - 188s 2s/step - loss: 0.1420 - accuracy: 0.9947 - val_loss: 1.9804 - val_accuracy: 0.5163 - lr: 1.0000e-04
# Epoch 14/15
# 100/100 [==============================] - 185s 2s/step - loss: 0.1183 - accuracy: 0.9941 - val_loss: 1.9726 - val_accuracy: 0.5125 - lr: 1.0000e-04
# Epoch 15/15
# 100/100 [==============================] - 187s 2s/step - loss: 0.0952 - accuracy: 0.9972 - val_loss: 1.9664 - val_accuracy: 0.5350 - lr: 1.0000e-04

# %% [markdown]
# ### Visualization

# %%
fig1 = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.axis(ymin=0.1,ymax=1)
plt.grid()
plt.title('ResNet Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.savefig('ResNet_accuracy.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.grid()
plt.title('ResNet Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# ---
# ## Implementation of the VGG16 Model

# %%
vgg_16_model = Sequential()

pretrained_model= tf.keras.applications.VGG16(include_top=False,
                   input_shape=(200,200,3),
                   pooling='avg',classes=80,
                   weights='imagenet')

for layer in pretrained_model.layers:
        layer.trainable=False

vgg_16_model.add(pretrained_model)
vgg_16_model.add(Flatten())
vgg_16_model.add(Dense(1024, activation='relu'))
vgg_16_model.add(Dense(512, activation='relu'))
vgg_16_model.add(Dense(80, activation='softmax'))

# %%
vgg_16_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 512)               14714688
#
#  module_wrapper_4 (ModuleWr  (None, 512)               0
#  apper)
#
#  module_wrapper_5 (ModuleWr  (None, 1024)              525312
#  apper)
#
#  module_wrapper_6 (ModuleWr  (None, 512)               524800
#  apper)
#
#  module_wrapper_7 (ModuleWr  (None, 80)                41040
#  apper)
#
# =================================================================
# Total params: 15805840 (60.29 MB)
# Trainable params: 1091152 (4.16 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
vgg_16_model.compile(optimizer=Adam(learning_rate=0.0001), 
                     loss='sparse_categorical_crossentropy', 
                     metrics=['accuracy'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=4)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=2)
csv_logger = CSVLogger('VGG16_Training_History.csv')
epochs=15
history = vgg_16_model.fit(
  trainDataset,
  validation_data=validationDataset,
  epochs=epochs,
  callbacks=[early_stopping, reduce_lr])
# Out:
# Epoch 1/15
# 100/100 [==============================] - 486s 5s/step - loss: 5.4863 - accuracy: 0.0606 - val_loss: 4.2779 - val_accuracy: 0.0913 - lr: 1.0000e-04
# Epoch 2/15
# 100/100 [==============================] - 487s 5s/step - loss: 3.2359 - accuracy: 0.2472 - val_loss: 3.6523 - val_accuracy: 0.1813 - lr: 1.0000e-04
# Epoch 3/15
# 100/100 [==============================] - 485s 5s/step - loss: 2.2596 - accuracy: 0.4419 - val_loss: 3.3202 - val_accuracy: 0.2400 - lr: 1.0000e-04
# Epoch 4/15
# 100/100 [==============================] - 487s 5s/step - loss: 1.5770 - accuracy: 0.6269 - val_loss: 3.0915 - val_accuracy: 0.2975 - lr: 1.0000e-04
# Epoch 5/15
# 100/100 [==============================] - 495s 5s/step - loss: 1.0847 - accuracy: 0.7625 - val_loss: 2.9605 - val_accuracy: 0.3212 - lr: 1.0000e-04
# Epoch 6/15
# 100/100 [==============================] - 497s 5s/step - loss: 0.7383 - accuracy: 0.8591 - val_loss: 2.8745 - val_accuracy: 0.3425 - lr: 1.0000e-04
# Epoch 7/15
# 100/100 [==============================] - 493s 5s/step - loss: 0.5029 - accuracy: 0.9284 - val_loss: 2.8226 - val_accuracy: 0.3725 - lr: 1.0000e-04
# Epoch 8/15
# 100/100 [==============================] - 493s 5s/step - loss: 0.3445 - accuracy: 0.9666 - val_loss: 2.8077 - val_accuracy: 0.3862 - lr: 1.0000e-04
# Epoch 9/15
# 100/100 [==============================] - 487s 5s/step - loss: 0.2377 - accuracy: 0.9831 - val_loss: 2.7864 - val_accuracy: 0.3988 - lr: 1.0000e-04
# Epoch 10/15
# 100/100 [==============================] - 495s 5s/step - loss: 0.1707 - accuracy: 0.9931 - val_loss: 2.7862 - val_accuracy: 0.4013 - lr: 1.0000e-04
# Epoch 11/15
# 100/100 [==============================] - 493s 5s/step - loss: 0.1294 - accuracy: 0.9928 - val_loss: 2.7917 - val_accuracy: 0.4038 - lr: 1.0000e-04
# Epoch 12/15
# 100/100 [==============================] - 495s 5s/step - loss: 0.1021 - accuracy: 0.9947 - val_loss: 2.7807 - val_accuracy: 0.4150 - lr: 1.0000e-04
# Epoch 13/15
# 100/100 [==============================] - 491s 5s/step - loss: 0.0811 - accuracy: 0.9956 - val_loss: 2.7993 - val_accuracy: 0.4175 - lr: 1.0000e-04
# Epoch 14/15
# 100/100 [==============================] - 487s 5s/step - loss: 0.0793 - accuracy: 0.9937 - val_loss: 2.8237 - val_accuracy: 0.4112 - lr: 1.0000e-04
# Epoch 15/15
# 100/100 [==============================] - 487s 5s/step - loss: 0.0623 - accuracy: 0.9962 - val_loss: 2.7705 - val_accuracy: 0.4187 - lr: 1.0000e-05

# %%
fig1 = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.axis(ymin=0.1,ymax=1)
plt.grid()
plt.title('VGG16 Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'test'])
plt.savefig('VGG16_accuracy.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.grid()
plt.title('VGG16 Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# %% [markdown]
# ## Evaluation of the ResNet Model

# %%
resnet_model_evaluation = resnetModel.evaluate(validationDataset)

print("ResNet Model Evaluation:")
print("Test Loss:", resnet_model_evaluation[0])
print("Test Accuracy:", resnet_model_evaluation[1])
# Out:
# 25/25 [==============================] - 33s 1s/step - loss: 1.9664 - accuracy: 0.5350
# ResNet Model Evaluation:
# Test Loss: 1.966442584991455
# Test Accuracy: 0.5350000262260437

# %% [markdown]
# ## Evaluation of the VGG16 Model

# %%
vgg16_model_evaluation = vgg_16_model.evaluate(validationDataset)

print("VGG16 Model Evaluation:")
print("Test Loss:", vgg16_model_evaluation[0])
print("Test Accuracy:", vgg16_model_evaluation[1])
# Out:
# 25/25 [==============================] - 102s 4s/step - loss: 2.7705 - accuracy: 0.4187
# VGG16 Model Evaluation:
# Test Loss: 2.7705307006835938
# Test Accuracy: 0.41874998807907104

# %%
# Convert test labels to class labels
testLabels = []
for images, labels in validationDataset:
    testLabels.extend(labels.numpy())

testLabels = np.array(testLabels)

# %% [markdown]
# ## Result Analysis of the ResNet Model

# %%
import pandas as pd

resnet_predictions = resnetModel.predict(validationDataset)
resnet_pred_labels = np.argmax(resnet_predictions, axis=1)
report = classification_report(testLabels, resnet_pred_labels, target_names=classNames, output_dict=True)

# Plot precision, recall, and F1-score
metrics_df = pd.DataFrame(report).transpose()
metrics_df.drop(['accuracy', 'macro avg', 'weighted avg'], inplace=True)
sns.heatmap(metrics_df[['precision', 'recall', 'f1-score']], annot=True, cmap='Blues', fmt=".2f")
plt.title('ResNet Model Metrics')
plt.show()
# Out:
# 25/25 [==============================] - 33s 1s/step
# C:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Python310\lib\site-packages\sklearn\metrics\_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## Result Analysis of the VGG16 Model

# %%
import pandas as pd
import seaborn as sns

vgg16_predictions = vgg_16_model.predict(validationDataset)
vgg16_pred_labels = np.argmax(vgg16_predictions, axis=1)
report = classification_report(testLabels, vgg16_pred_labels, target_names=classNames, output_dict=True)

# Plot precision, recall, and F1-score
metrics_df = pd.DataFrame(report).transpose()
metrics_df.drop(['accuracy', 'macro avg', 'weighted avg'], inplace=True)
sns.heatmap(metrics_df[['precision', 'recall', 'f1-score']], annot=True, cmap='Blues', fmt=".2f")
plt.title('VGG16 Model Metrics')
plt.show()
# Out:
# 25/25 [==============================] - 86s 3s/step

# %% [markdown]
# ---
# ## Conclusion
#
# After a comprehensive assessment of both the VGG16 and ResNet models applied to the Indian Food dataset, a clear trend emerges favoring the ResNet architecture over VGG16. The ResNet model showcases superior performance in key metrics such as accuracy, precision, recall, and F1-score, attesting to its capability to discern and classify Indian food items more accurately. This proficiency is attributed to ResNet's adeptness at capturing intricate features and patterns within the dataset.
#
# While the ResNet model exhibits superior overall performance, it's essential to acknowledge that certain features were better predicted by the VGG16 model, as evidenced by the heatmap metrics. This nuanced observation suggests that each model has its strengths, and the choice between them may depend on the specific characteristics of the features under consideration.
#
# In summary, while the ResNet model demonstrates overall superiority, the nuanced strengths of the VGG16 model in certain aspects underscore the importance of careful consideration and potentially exploring ensemble approaches to harness the complementary strengths of both architectures.
